# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# %%
# Load the dataset
data = pd.read_excel('pvistats.xlsx')

# %%
data.head(5)
# Out:
#              DateTime  DlyEn       TotEn  ParEn        WkE        MnE  \
# 0 2021-03-02 09:24:21  27263  150.513000    150  45.862999  45.862999
# 1 2021-03-02 09:26:21  27292  150.542007    150  45.891998  45.891998
# 2 2021-03-02 09:27:38  27307  150.557007    150  45.907001  45.907001
# 3 2021-03-02 09:29:38  27331  150.580994    150  45.931000  45.931000
# 4 2021-03-02 09:31:38  27352  150.602005    150  45.952000  45.952000
#
#           YrE       Gv3Ph     Gc3Ph       Gp3Ph  ...       InPv1     InPc1  \
# 0  150.263000  240.546692  1.472140  872.431885  ...  577.760437  0.784607
# 1  150.292007  240.109329  1.280641  747.328003  ...  574.940491  0.724182
# 2  150.307007  240.687103  1.347501  753.947266  ...  571.514038  0.693970
# 3  150.330994  240.889771  1.234056  675.178162  ...  576.092712  0.628967
# 4  150.352005  240.905365  1.210092  597.732849  ...  576.911438  0.556641
#
#         InPw2       InPv2     InPc2    InvTemp    BstTemp  IslRes  WGFreq  \
# ...

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['DateTime'], data['DlyEn'], marker='o', linestyle='-')
plt.title('Daily Energy Consumption')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))
plt.plot(data['DateTime'], data['TotEn'], marker='o', linestyle='-')
plt.title('Total Energy Consumption')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 10))
plt.plot(data['DateTime'], data['ParEn'], marker='o', linestyle='-')
plt.title('Energy Consumption per parameter')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.xticks(rotation=0)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
data_hourly = data.resample('H', on='DateTime').mean()
# Plotting
plt.figure(figsize=(10, 6))
plt.plot(data_hourly.index, data_hourly['DlyEn'], marker='o', linestyle='-')
plt.title('Hourly Average Energy Consumption')
plt.xlabel('Date and Time')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()
plt.show()

# %%
# Evaluate the model
mse = mean_squared_error(test_data['TotEn'], predictions)
rmse = np.sqrt(mse)
print("Root Mean Squared Error (RMSE):", rmse)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[7], line 2
#       1 # Evaluate the model
# ----> 2 mse = mean_squared_error(test_data['TotEn'], predictions)
#       3 rmse = np.sqrt(mse)
#       4 print("Root Mean Squared Error (RMSE):", rmse)
#
# NameError: name 'test_data' is not defined

# %%
import seaborn as sns
# Assuming df is your DataFrame
sns.set(style="whitegrid")  # Setting the style to whitegrid for a clean background
 
plt.figure(figsize=(12, 6))  # Setting the figure size
sns.lineplot(data=data, x='DateTime', y='DlyEn', label='High Price', color='blue')
 
# Adding labels and title
plt.xlabel('Date')
plt.ylabel('High')
plt.title('Share Highest Price Over Time')
 
plt.show()
