# %%
import pandas as pd

# Load the dataset from Excel file
df = pd.read_excel('pvistats.xlsx')

# Handle missing values if any (for demonstration purposes)
df.fillna(method='ffill', inplace=True)  # Forward fill missing values

# Convert DateTime column to datetime object
df['DateTime'] = pd.to_datetime(df['DateTime'])

# Explore the data
print(df.head())
print(df.info())
print(df.describe())
# Out:
#              DateTime  DlyEn       TotEn  ParEn        WkE        MnE  \
# 0 2021-03-02 09:24:21  27263  150.513000    150  45.862999  45.862999
# 1 2021-03-02 09:26:21  27292  150.542007    150  45.891998  45.891998
# 2 2021-03-02 09:27:38  27307  150.557007    150  45.907001  45.907001
# 3 2021-03-02 09:29:38  27331  150.580994    150  45.931000  45.931000
# 4 2021-03-02 09:31:38  27352  150.602005    150  45.952000  45.952000
#
#           YrE       Gv3Ph     Gc3Ph       Gp3Ph  ...       InPv1     InPc1  \
# 0  150.263000  240.546692  1.472140  872.431885  ...  577.760437  0.784607
# 1  150.292007  240.109329  1.280641  747.328003  ...  574.940491  0.724182
# 2  150.307007  240.687103  1.347501  753.947266  ...  571.514038  0.693970
# 3  150.330994  240.889771  1.234056  675.178162  ...  576.092712  0.628967
# 4  150.352005  240.905365  1.210092  597.732849  ...  576.911438  0.556641
#
#         InPw2       InPv2     InPc2    InvTemp    BstTemp  IslRes  WGFreq  \
# 0  470.904022  604.140808  0.803833  33.088150  33.972290      20       0
# 1  406.574127  597.894409  0.750732  32.990051  33.677246      20       0
# 2  400.035583  591.102234  0.726929  32.891998  33.480728      20       0
# 3  366.231415  602.412415  0.677490  32.891998  33.382507      20       0
# 4  325.634888  601.533081  0.569458  32.794067  33.382507      20       0
#
#    Phi3Ph
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1
#
# [5 rows x 22 columns]
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 130773 entries, 0 to 130772
# Data columns (total 22 columns):
#  #   Column    Non-Null Count   Dtype
# ---  ------    --------------   -----
#  0   DateTime  130773 non-null  datetime64[ns]
#  1   DlyEn     130773 non-null  int64
#  2   TotEn     130773 non-null  float64
#  3   ParEn     130773 non-null  int64
#  4   WkE       130773 non-null  float64
#  5   MnE       130773 non-null  float64
#  6   YrE       130773 non-null  float64
#  7   Gv3Ph     130773 non-null  float64
#  8   Gc3Ph     130773 non-null  float64
#  9   Gp3Ph     130773 non-null  float64
#  10  Freq3Ph   130773 non-null  float64
#  11  InPw1     130773 non-null  float64
#  12  InPv1     130773 non-null  float64
#  13  InPc1     130773 non-null  float64
#  14  InPw2     130773 non-null  float64
#  15  InPv2     130773 non-null  float64
#  16  InPc2     130773 non-null  float64
#  17  InvTemp   130773 non-null  float64
#  18  BstTemp   130773 non-null  float64
#  19  IslRes    130773 non-null  int64
#  20  WGFreq    130773 non-null  int64
#  21  Phi3Ph    130773 non-null  int64
# dtypes: datetime64[ns](1), float64(16), int64(5)
# memory usage: 21.9 MB
# None
#               DlyEn          TotEn          ParEn            WkE  \
# count  1.307730e+05  130773.000000  130773.000000  130773.000000
# mean   3.517801e+04    9240.316385    9240.324669     103.199326
# std    1.747413e+06    6011.066149    6021.247933    1623.935735
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    1.945000e+03    3744.762939    3744.000000      39.910000
# 50%    1.104700e+04   11639.333984   11639.000000      78.650002
# 75%    2.105300e+04   13444.569336   13444.000000     123.831001
# max    1.347441e+08  134744.062500  134744.000000  134744.062500
#
#                  MnE            YrE          Gv3Ph          Gc3Ph  \
# count  130773.000000  130773.000000  130773.000000  130773.000000
# mean      388.919236    4121.043905     236.324752       2.942746
# std      1679.642036    2702.391995      22.608536       2.741615
# min         0.000000       0.000000       0.000000       0.000000
# 25%       153.447006    2626.603027     233.563187       0.997867
# 50%       356.197998    4105.682129     239.263596       1.745219
# 75%       565.450989    5037.057129     242.458603       3.849538
# max    134744.062500  134744.062500     257.155243      15.736776
#
#                Gp3Ph        Freq3Ph  ...          InPv1          InPc1  \
# count  130773.000000  130773.000000  ...  130773.000000  130773.000000
# mean     1863.765657      49.579820  ...     505.284505       1.841947
# std      2072.671313       4.577572  ...     100.315594       2.080766
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%       309.133392      49.965023  ...     511.597260       0.357056
# 50%      1116.682373      50.010002  ...     535.733765       1.064758
# 75%      2676.178711      50.044037  ...     550.925232       2.483826
# max     10987.976562      50.528530  ...     653.748047      12.599487
#
#                InPw2          InPv2          InPc2        InvTemp  \
# count  130773.000000  130773.000000  130773.000000  130773.000000
# mean      993.485239     502.198974       1.946601      33.813358
# std      1120.621728     109.193238       2.201277       7.969780
# min         0.000000       0.000000       0.000000       0.000000
# 25%       156.645767     512.658508       0.346985      29.289490
# 50%       573.083130     537.765381       1.098633      34.366302
# 75%      1404.432861     552.805237       2.671509      38.649582
# max      6040.464844     653.748047      11.683044      56.952011
#
#              BstTemp         IslRes    WGFreq         Phi3Ph
# count  130773.000000  130773.000000  130773.0  130773.000000
# mean       34.965352      19.789406       0.0       0.991137
# std         9.138338       2.041460       0.0       0.093724
# min         0.000000       0.000000       0.0       0.000000
# 25%        29.483002      20.000000       0.0       1.000000
# 50%        35.354019      20.000000       0.0       1.000000
# 75%        40.992737      20.000000       0.0       1.000000
# max        60.874336      20.000000       0.0       1.000000
#
# [8 rows x 21 columns]

# %%
df["DlyEn"].describe()
# Out:
# count    1.307730e+05
# mean     3.517801e+04
# std      1.747413e+06
# min      0.000000e+00
# 25%      1.945000e+03
# 50%      1.104700e+04
# 75%      2.105300e+04
# max      1.347441e+08
# Name: DlyEn, dtype: float64

# %%
df.shape
# Out:
# (130773, 22)

# %%
df.head(2000)
# Out:
#                 DateTime  DlyEn       TotEn  ParEn        WkE         MnE  \
# 0    2021-03-02 09:24:21  27263  150.513000    150  45.862999   45.862999
# 1    2021-03-02 09:26:21  27292  150.542007    150  45.891998   45.891998
# 2    2021-03-02 09:27:38  27307  150.557007    150  45.907001   45.907001
# 3    2021-03-02 09:29:38  27331  150.580994    150  45.931000   45.931000
# 4    2021-03-02 09:31:38  27352  150.602005    150  45.952000   45.952000
# ...                  ...    ...         ...    ...        ...         ...
# 1995 2021-03-09 04:33:54  23661  339.510986    339  49.111000  234.860992
# 1996 2021-03-09 04:35:54  23680  339.529999    339  49.130001  234.880005
# 1997 2021-03-09 04:37:55  23694  339.544006    339  49.144001  234.893997
# 1998 2021-03-09 04:39:55  23709  339.558990    339  49.159000  234.908997
# 1999 2021-03-09 04:41:55  23720  339.570007    339  49.169998  234.919998
#
#              YrE       Gv3Ph     Gc3Ph       Gp3Ph  ...       InPv1     InPc1  \
# 0     150.263000  240.546692  1.472140  872.431885  ...  577.760437  0.784607
# 1     150.292007  240.109329  1.280641  747.328003  ...  574.940491  0.724182
# 2     150.307007  240.687103  1.347501  753.947266  ...  571.514038  0.693970
# 3     150.330994  240.889771  1.234056  675.178162  ...  576.092712  0.628967
# 4     150.352005  240.905365  1.210092  597.732849  ...  576.911438  0.556641
# ...          ...         ...       ...         ...  ...         ...       ...
# 1995  339.260986  234.845474  1.160679  550.074280  ...  569.785706  0.560303
# 1996  339.279999  235.276642  0.997867  503.077515  ...  568.148254  0.525513
# 1997  339.294006  234.397476  1.026797  440.194611  ...  564.994751  0.468750
# 1998  339.308990  234.589569  0.872610  379.297485  ...  562.659973  0.407410
# 1999  339.320007  234.653564  0.872610  334.948456  ...  559.476135  0.371704
#
#            InPw2       InPv2     InPc2    InvTemp    BstTemp  IslRes  WGFreq  \
# 0     470.904022  604.140808  0.803833  33.088150  33.972290      20       0
# 1     406.574127  597.894409  0.750732  32.990051  33.677246      20       0
# 2     400.035583  591.102234  0.726929  32.891998  33.480728      20       0
# 3     366.231415  602.412415  0.677490  32.891998  33.382507      20       0
# 4     325.634888  601.533081  0.569458  32.794067  33.382507      20       0
# ...          ...         ...       ...        ...        ...     ...     ...
# 1995  291.174561  577.487549  0.546570  31.620880  32.109085      20       0
# 1996  261.868866  574.728210  0.527344  31.523376  31.816071      20       0
# 1997  231.546844  574.000488  0.466003  31.425873  31.816071      20       0
# 1998  197.681091  569.725037  0.416565  31.328400  31.620880      20       0
# 1999  172.694031  568.785034  0.356140  31.230957  31.425873      20       0
#
#       Phi3Ph
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 1995       1
# 1996       1
# 1997       1
# 1998       1
# 1999       1
#
# [2000 rows x 22 columns]

# %% [markdown]
# ### Analyse Data

# %%
import matplotlib.pyplot as plt
data = df
# Reset index to ensure continuous datetime index
data.reset_index(drop=True, inplace=True)

list1 = ['DlyEn', 'TotEn', 'ParEn', 'WkE', 'MnE', 'YrE']

for i in list1:
    # Plotting the real data
    plt.figure(figsize=(10, 6))
    plt.plot(data.index, data[i], color='blue')
    plt.title('Energy Consumption Over Time')
    plt.xlabel('Date')
    plt.ylabel(i)
    plt.grid(True)
    plt.show()

# %%
data["TotEn"].head(5)
# Out:
# 0    150.513000
# 1    150.542007
# 2    150.557007
# 3    150.580994
# 4    150.602005
# Name: TotEn, dtype: float64

# %% [markdown]
# Above Graph is distorted means we have to got with oulier detection

# %%
# Calculate the first and third quartiles
data = df
Q1 = data['TotEn'].quantile(0.25)
Q3 = data['TotEn'].quantile(0.75)

# Interquartile range
IQR = Q3 - Q1

# Define the lower and upper bounds
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the outliers
data_filtered = data[(data['TotEn'] >= lower_bound) & (data['TotEn'] <= upper_bound)]

# Plot the line graph without outliers
plt.figure(figsize=(10, 6))
plt.plot(data_filtered.index, data_filtered['TOtEn'], color='blue', label='Total Energy Consumption (Outliers Removed)')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.title('Total Energy Consumption Over Time (Outliers Removed)')
plt.legend()
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Image processing softwares\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Image processing softwares\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Image processing softwares\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'TOtEn'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[7], line 18
#      16 # Plot the line graph without outliers
#      17 plt.figure(figsize=(10, 6))
# ---> 18 plt.plot(data_filtered.index, data_filtered['TOtEn'], color='blue', label='Total Energy Consumption (Outliers Removed)')
#      19 plt.xlabel('Date')
#      20 plt.ylabel('Energy Consumption')
#
# File D:\Image processing softwares\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\Image processing softwares\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'TOtEn'

# %%
data_filtered.describe()
# Out:
#               DlyEn          TotEn          ParEn            WkE  \
# count  1.307530e+05  130753.000000  130753.000000  130753.000000
# mean   1.457292e+04    9221.119312    9221.127607      84.664313
# std    5.270525e+05    5807.645962    5818.185585     376.310989
# min    0.000000e+00       0.000000       0.000000       0.000000
# 25%    1.944000e+03    3744.042969    3743.000000      39.905998
# 50%    1.104400e+04   11638.389648   11637.000000      78.635002
# 75%    2.104800e+04   13444.500000   13444.000000     123.825996
# max    1.347441e+08   19142.000000  134744.000000  134744.062500
#
#                  MnE            YrE          Gv3Ph          Gc3Ph  \
# count  130753.000000  130753.000000  130753.000000  130753.000000
# mean      370.428578    4105.160532     236.326693       2.943196
# std       579.869607    2283.752217      22.590893       2.741583
# min         0.000000       0.000000       0.000000       0.000000
# 25%       153.417999    2626.593994     233.563187       0.997867
# 50%       356.147003    4105.446777     239.263596       1.761920
# 75%       565.335022    5036.990234     242.458603       3.849538
# max    134744.062500  134744.062500     257.155243      15.736776
#
#                Gp3Ph        Freq3Ph  ...          InPv1          InPc1  \
# count  130753.000000  130753.000000  ...  130753.000000  130753.000000
# mean     1864.050739      49.582053  ...     505.346074       1.842227
# std      2072.701637       4.565583  ...     100.196011       2.080803
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%       309.133392      49.965023  ...     511.597260       0.357056
# 50%      1117.344238      50.010002  ...     535.733765       1.064758
# 75%      2676.840576      50.044037  ...     550.925232       2.483826
# max     10987.976562      50.528530  ...     653.748047      12.599487
#
#                InPw2          InPv2          InPc2        InvTemp  \
# count  130753.000000  130753.000000  130753.000000  130753.000000
# mean      993.637203     502.263903       1.946898      33.816942
# std      1120.640061     109.072638       2.201314       7.964072
# min         0.000000       0.000000       0.000000       0.000000
# 25%       156.769699     512.688843       0.347900      29.289490
# 50%       573.275269     537.765381       1.098633      34.366302
# 75%      1404.679932     552.805237       2.672424      38.649582
# max      6040.464844     653.748047      11.683044      56.952011
#
#              BstTemp         IslRes    WGFreq         Phi3Ph
# count  130753.000000  130753.000000  130753.0  130753.000000
# mean       34.969615      19.792433       0.0       0.991266
# std         9.131742       2.026891       0.0       0.093047
# min         0.000000       0.000000       0.0       0.000000
# 25%        29.483002      20.000000       0.0       1.000000
# 50%        35.354019      20.000000       0.0       1.000000
# 75%        40.992737      20.000000       0.0       1.000000
# max        60.874336      20.000000       0.0       1.000000
#
# [8 rows x 21 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming 'data' is your DataFrame with the 'TotEn' column

# Calculate the first quartile (Q1)
Q1 = data['TotEn'].quantile(0.25)

# Calculate the third quartile (Q3)
Q3 = data['TotEn'].quantile(0.75)

# Calculate the interquartile range (IQR)
IQR = Q3 - Q1

# Define lower and upper bounds for outlier detection
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out the data points within the bounds
data_no_outliers = data[(data['TotEn'] >= lower_bound) & (data['TotEn'] <= upper_bound)]

# Plot the total energy consumption after outlier removal
plt.figure(figsize=(10, 6))
plt.plot(data_no_outliers['DateTime'], data_no_outliers['TotEn'], color='blue', label='Total Energy (No Outliers)')
plt.xlabel('DateTime')
plt.ylabel('Total Energy')
plt.title('Total Energy Consumption after Outlier Removal (IQR Method)')
plt.legend()
plt.grid(True)
plt.show()

# %%
count = 1
for i in data_no_outliers['TotEn']:
    if(i==0):
        count += 1
print(count)
# Out:
# 1067

# %%
# Filter out zero values
data_no_outliers_no_zeros = data_no_outliers[data_no_outliers['TotEn'] != 0]

# Plot the total energy consumption after removing zero values
plt.figure(figsize=(10, 6))
plt.plot(data_no_outliers_no_zeros['DateTime'], data_no_outliers_no_zeros['TotEn'], color='blue', label='Total Energy (No Outliers or Zeros)')
plt.xlabel('DateTime')
plt.ylabel('Total Energy')
plt.title('Total Energy Consumption after Outlier Removal (IQR Method) and Zero Value Removal')
plt.legend()
plt.grid(True)
plt.show()

# %%
data_no_outliers_no_zeros.TotEn.head(9000)
# Out:
# 0        150.513000
# 1        150.542007
# 2        150.557007
# 3        150.580994
# 4        150.602005
#            ...
# 9061    2195.085938
# 9062    2195.134033
# 9063    2195.189941
# 9064    2195.237061
# 9065    2195.277100
# Name: TotEn, Length: 9000, dtype: float64

# %%
for j in data_no_outliers_no_zeros.DateTime>"2022-10-02 09:29:38":
    if data_no_outliers_no_zeros["TotEn"] <= 2500.00:
        print(data_no_outliers_no_zeros["TotEn"], data_no_outliers_no_zeros.DateTime)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[13], line 2
#       1 for j in data_no_outliers_no_zeros.DateTime>"2022-10-02 09:29:38":
# ----> 2     if data_no_outliers_no_zeros["TotEn"] <= 2500.00:
#       3         print(data_no_outliers_no_zeros["TotEn"], data_no_outliers_no_zeros.DateTime)
#
# File D:\Image processing softwares\lib\site-packages\pandas\core\generic.py:1527, in NDFrame.__nonzero__(self)
#    1525 @final
#    1526 def __nonzero__(self) -> NoReturn:
# -> 1527     raise ValueError(
#    1528         f"The truth value of a {type(self).__name__} is ambiguous. "
#    1529         "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1530     )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
import pandas as pd

# Assuming data_no_outliers_no_zeros is your DataFrame

# Convert DateTime column to datetime type if it's not already
data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])

# Filter data
filtered_data = data_no_outliers_no_zeros[(data_no_outliers_no_zeros['DateTime'] > "2022-10-02 09:29:38") & (data_no_outliers_no_zeros['TotEn'] <= 2500.00)]

# Print filtered data
for index, row in filtered_data.iterrows():
    print(row['TotEn'], row['DateTime'])

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Assuming data_no_outliers_no_zeros is your DataFrame

# Convert DateTime column to datetime type if it's not already
data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])

# Filter data
filtered_data = data_no_outliers_no_zeros[(data_no_outliers_no_zeros['DateTime'] > "2022-10-02 09:29:38") & (data_no_outliers_no_zeros['TotEn'] <= 2500.00)]

# Drop filtered rows
data_no_outliers_no_zeros = data_no_outliers_no_zeros.drop(filtered_data.index)

# Plot total energy
plt.figure(figsize=(10, 6))
plt.plot(data_no_outliers_no_zeros['DateTime'], data_no_outliers_no_zeros['TotEn'], color='blue')
plt.title('Total Energy Consumption over Time')
plt.xlabel('DateTime')
plt.ylabel('Total Energy Consumption')
plt.grid(True)
plt.show()
# Out:
# C:\Users\ajayp\AppData\Local\Temp\ipykernel_7988\2043448743.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])

# %%
# Assuming data_no_outliers_no_zeros is your DataFrame
# Convert DateTime column to datetime type if it's not already
data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])

# Set DateTime column as the index
data_no_outliers_no_zeros.set_index('DateTime', inplace=True)

# Resample the data to daily frequency and sum the total energy consumption
daily_energy_consumption = data_no_outliers_no_zeros['TotEn'].resample('D').sum()

print(daily_energy_consumption)
# Out:
# DateTime
# 2021-03-02    3.315610e+03
# 2021-03-03    1.381856e+04
# 2021-03-04    7.257105e+04
# 2021-03-05    7.519840e+04
# 2021-03-06    2.596918e+04
#                   ...
# 2023-04-02    7.094356e+06
# 2023-04-03    7.258345e+06
# 2023-04-04    7.271969e+06
# 2023-04-05    7.193530e+06
# 2023-04-06    6.635119e+06
# Freq: D, Name: TotEn, Length: 766, dtype: float64

# %%
import matplotlib.pyplot as plt

# Assuming you have already calculated daily_energy_consumption
plt.figure(figsize=(10, 6))
daily_energy_consumption.plot()
plt.title('Daily Energy Consumption')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt

# Filter out rows where daily_energy_consumption is not zero
non_zero_daily_energy = daily_energy_consumption[daily_energy_consumption != 0]

plt.figure(figsize=(10, 6))
non_zero_daily_energy.plot()
plt.title('Daily Energy Consumption (Non-zero values)')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.show()

# %%
import numpy as np

# Calculate the first and third quartiles
Q1 = daily_energy_consumption.quantile(0.25)
Q3 = daily_energy_consumption.quantile(0.75)

# Calculate the IQR
IQR = Q3 - Q1

# Define the lower and upper bounds for outliers
lower_bound = Q1 - 1.5 * IQR
upper_bound = Q3 + 1.5 * IQR

# Filter out rows where daily_energy_consumption is within the bounds
filtered_daily_energy = daily_energy_consumption[(daily_energy_consumption >= lower_bound) & (daily_energy_consumption <= upper_bound)]

# Plot the filtered data
plt.figure(figsize=(10, 6))
filtered_daily_energy.plot()
plt.title('Daily Energy Consumption (Outliers Removed)')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.show()

# %%
# Filter out rows where daily_energy_consumption is greater than zero
filtered_daily_energy_no_zeros = filtered_daily_energy[filtered_daily_energy > 0]

# Plot the filtered data without zero values
plt.figure(figsize=(10, 6))
filtered_daily_energy_no_zeros.plot()
plt.title('Daily Energy Consumption (Outliers and Zeros Removed)')
plt.xlabel('Date')
plt.ylabel('Energy Consumption')
plt.grid(True)
plt.show()

# %%
daily_energy_consumption.describe()
# Out:
# count    7.660000e+02
# mean     1.574005e+06
# std      2.177139e+06
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      2.572603e+06
# max      7.271969e+06
# Name: TotEn, dtype: float64

# %%
import pandas as pd

# Assuming data_no_outliers_no_zeros is your DataFrame

# Convert DateTime column to datetime type if it's not already
data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])

# Set DateTime column as the index
data_no_outliers_no_zeros.set_index('DateTime', inplace=True)

# Resample data on a weekly basis and sum the 'TotEn' values for each week
weekly_energy_consumption = data_no_outliers_no_zeros['TotEn'].resample('W').sum()

print(weekly_energy_consumption)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File D:\Image processing softwares\lib\site-packages\pandas\core\indexes\base.py:3802, in Index.get_loc(self, key, method, tolerance)
#    3801 try:
# -> 3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
#
# File D:\Image processing softwares\lib\site-packages\pandas\_libs\index.pyx:138, in pandas._libs.index.IndexEngine.get_loc()
#
# File D:\Image processing softwares\lib\site-packages\pandas\_libs\index.pyx:165, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\_libs\hashtable_class_helper.pxi:5745, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\_libs\hashtable_class_helper.pxi:5753, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'DateTime'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[21], line 6
#       1 import pandas as pd
#       3 # Assuming data_no_outliers_no_zeros is your DataFrame
#       4
#       5 # Convert DateTime column to datetime type if it's not already
# ----> 6 data_no_outliers_no_zeros['DateTime'] = pd.to_datetime(data_no_outliers_no_zeros['DateTime'])
#       8 # Set DateTime column as the index
#       9 data_no_outliers_no_zeros.set_index('DateTime', inplace=True)
#
# File D:\Image processing softwares\lib\site-packages\pandas\core\frame.py:3807, in DataFrame.__getitem__(self, key)
#    3805 if self.columns.nlevels > 1:
#    3806     return self._getitem_multilevel(key)
# -> 3807 indexer = self.columns.get_loc(key)
#    3808 if is_integer(indexer):
#    3809     indexer = [indexer]
#
# File D:\Image processing softwares\lib\site-packages\pandas\core\indexes\base.py:3804, in Index.get_loc(self, key, method, tolerance)
#    3802     return self._engine.get_loc(casted_key)
#    3803 except KeyError as err:
# -> 3804     raise KeyError(key) from err
#    3805 except TypeError:
#    3806     # If we have a listlike key, _check_indexing_error will raise
#    3807     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3808     #  the TypeError.
#    3809     self._check_indexing_error(key)
#
# KeyError: 'DateTime'
